# %% [markdown]
# # 01 — Data Loading & Cleaning
#
# **Objective:** Load the Open Food Facts bulk database, filter to EU countries, and clean for analysis.
#
# ## Steps
# 1. Download OFF Parquet dump and load with `load_off.py`
# 2. Initial data profiling: shape, missing values, type distributions
# 3. Brand normalisation (accent stripping, fuzzy grouping of variants)
# 4. Category harmonisation into 2-level hierarchy
# 5. Deduplication
# 6. Compute Nutri-Score for products missing official grades
# 7. Build NOVA heuristic for products without classification
# 8. Export analysis-ready dataset
#
# ## Data Quality Report
# Document all cleaning decisions, record counts before/after each step.

# %%
import pandas as pd
import numpy as np
from pathlib import Path

from src.data.load_off import load_off_parquet
from src.data.clean import normalise_brands, deduplicate_products, harmonise_categories
from src.data.nutriscore import compute_nutriscore_column

# %%
# TODO: Download OFF parquet and load
# df = load_off_parquet(Path('data/raw/openfoodfacts.parquet'))
